# %%
print('HEllo World')
# Out:
# HEllo World

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5//2)
# Out:
# 2

# %%
print('HEllo\bwrld')
print('HEllo\\wrld')
print("\'HEllowrld'")
# Out:
# wrld
# HEllo\wrld
# 'HEllowrld'

# %%
a='ABCD'
b='EFGH'
print(a+" "+b)
type(a)
# Out:
# ABCD EFGH
# str

# %%
c=input("name")
d=int(input("age"))
e=c+str(d)
print(e)
# Out:
# nameab
# age8
# ab8

# %%
var1=0o123
var2=0x23
print(var1+var2)
# Out:
# 118

# %% [markdown]
# a=5
# b=2
# c=a>b
# d=a<b
# print(c,d)

# %%
a=10
b=15
temp=a
a=b
b=temp
print(a,b)
# Out:
# 15 10

# %%
a=int(input("A"))
b=int(input("B"))
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# A5
# B2
# 2 5

# %%
print("Hello"+" "+input("name")+"!")
# Out:
# namesita
# Hello sita!

# %%
name=input("Name")
age=int(input("age"))
print(f"My name is {name} and I'm {age} year old")
# Out:
# NameAnil
# age19
# My name is Anil and I'm 19 year old

# %%
#compare bitwise operator
print(6 & 3)
# Out:
# 2

# %%
print("cube of the no is",
      int(input("No"))**3)
# Out:
# No2
# cube of the no is 8

# %%
list1=[1,True,"apple","banana","cherry"]
print(list1)
print(len(list1))
print(type(list1))
print(tuple(list1))
print(list1[1])
print(list1[-1])
print(list1[2:5])
print(list1[::-1])
# Out:
# [1, True, 'apple', 'banana', 'cherry']
# 5
# <class 'list'>
# (1, True, 'apple', 'banana', 'cherry')
# True
# cherry
# ['apple', 'banana', 'cherry']
# ['cherry', 'banana', 'apple', True, 1]

# %%
tup1=("John","Daniel","Vicky")
print('#'.join(tup1))
a=":"
b="RohithJerry"
print(a.join(b))
# Out:
# John#Daniel#Vicky
# R:o:h:i:t:h:J:e:r:r:y

# %%
str1="Hello Im under the water Help me."
print(str1.split())
print(str1.split([sep='.']))
# Out:
#   File "<ipython-input-54-880dc1a2a429>", line 3
#     print(str1.split([sep='.']))
#                       ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
age=int(input("AGE"))
if age>18:
  print("Eligible")
else:
  print("NOt")
# Out:
# AGE30
# Eligible

# %%
a=int(input("A"))
b=int(input("B"))
c=int(input("C"))
if a>=b and a>=c:
  print(a,"is larger")
elif b>=a and b>=c:
  print(b,"is greater")
else:
  print(c, "is greater")
# Out:
# A3
# B3
# C1
# 3 is larger

# %%
a,b,c=input("A").split()
if int(a)>=int(b) and int(a)>=int(c):
  print(a,"is larger")
elif int(b)>=int(a) and int(b)>=int(c):
  print(b,"is greater")
else:
  print(c, "is greater")
# Out:
# A1 2 3
# 3 is greater

# %%
for _ in range(10):
  print("@")
# Out:
# @
# @
# @
# @
# @
# @
# @
# @
# @
# @

# %%
list5=[5,8,9,10,25]
list6=[]
for i in list5:
  list6.append(i**2)
print(list6)
# Out:
# [25, 64, 81, 100, 625]

# %%
list7=[]
for i in list5:
  if i%2==0:
    list7.append(i)
print(list7)
# Out:
# [8, 10]

# %%
list8=[]
i=1
while(i<51):
  if i%5==0 or i%7==0:
    list8.append(i)
  i+=1
print(list8)
# Out:
# [5, 7, 10, 14, 15, 20, 21, 25, 28, 30, 35, 40, 42, 45, 49, 50]

# %%
a=0
n=int(input("No"))
for i in range(1,n+1):
  a=a+(1/i)
print(a)
# Out:
# No5
# 2.283333333333333

# %%
a=0
n=int(input("No"))
for i in range(1,n+1):
  a=a+((i**i)/i)
print(a)
# Out:
# No5
# 701.0
