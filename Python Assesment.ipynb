# %%
print("p","q","r",sep='=')
# Out:
# p=q=r

# %%
print('pqr',end='#')
print('pqr')
# Out:
# pqr#pqr

# %%
T=("1","1"+"1","1"+"1"+"1")
print(T[2])
# Out:
# 111

# %%
string=input("AAA")
print(type(string))
s=0
for i in string:
  s=s+1
print(s)
size=2**s
print (size)
# Out:
# AAAhai
# <class 'str'>
# 3
# 8

# %%
string=input("AAA")
print(2**len(string))
# Out:
# AAAhai
# 8

# %%
x=int(input("NO "))
coeff=(1,2,-3,0,5)
coeff1=coeff[::-1]
for i in coeff1:
  exp=1*coeff1[0]+x
# Out:
# NO 4
# (5, 0, -3, 2, 1)

# %%
x=int(input("no "))
n=int(input("A"))
exp=0
for i in range(n+1):
  exp=exp+(x**i)
print(exp)
# Out:
# no 2
# A2
# 7

# %%
dob="29/08/2000"
if len(dob)>=5 and dob[3:5]=="08":
  print("aug")
# Out:
# aug

# %%
num=[65,32,-3,32,43,32,-22,2,-5,64,0,8]
i=0
for n in num:
  if 2**i==n:
    print(n)
  i=i+1
# Out:
# 32

# %%
import math
for n in range(3,100):
  for i in range(2,int(math.sqrt(n))+1):
    if i*i==n:
      print(n)
# Out:
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
n=int(input())
sumf=0
for i in range(0,n):
  for j in range(0,n):
    if i*j==n:
      break
    else:
      continue
    sumf=sumf+i
print(sumf)
# Out:
# 10
# 0
