# %%
import numpy as np
pmean=0
qmean=0
rmean=0
p=np.array([10,15,20,25,30])
q=np.array([60,75,85,95,100])
r=np.array([110,120,125,130,135])
for i in range(0,5):
  pmean=p[i]+pmean
print(pmean)
# Out:
# 100
