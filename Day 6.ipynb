# %% [markdown]
# LIST[ ], TUPLE( ), SET{ }, DICT{ }

# %%
a=[1,2,2,3,4,5,6]
b=(1,2,3,4,5,6)
c={1,2,3,4,5,6}
a.append(50)
a.append(20)
a.remove(2)
a.remove(2)
a.extend([24,25,26])
print(a)
print(b)
print(c)
# Out:
# [1, 3, 4, 5, 6, 50, 20, 24, 25, 26]
# (1, 2, 3, 4, 5, 6)
# {1, 2, 3, 4, 5, 6}

# %%
x = []
for i in range(0,5):
  x.extend([int(input("Enter"))])
x.insert(2,60)
x.pop()
print(x)
x.reverse()
print("Length=",len(x))
print(x[1:4])
print(min(x),max(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-30eaf4e963ee> in <cell line: 2>()
#       1 x = []
#       2 for i in range(0,5):
# ----> 3   x.extend([int(input("Enter"))])
#       4 x.insert(2,60)
#       5 x.pop()
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
x.clear()
for i in range(0,5):

  x.extend([int(input("Enter"))])
x.insert(2,60)
print(x[::])
print(x[3:1:-1])

print(x.pop())
print(x)

# %%
# dict={1:"Abey",2:"Arun"}
# #    key:value,key:value
# #dict.key()
# #dict.values()

# %%
diction={1:"ABey",2:"cherry"}
print(diction)
diction.update({3:"Shashi"})
print(diction)

# %%
x = {}
type(x)

# %%
h = {}
y={}
for i in range(0,2):
  h.update({int(input("KEY: ")):input("Value: ")})


print(h)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-00880751f099> in <cell line: 2>()
#       1 a = [1,2,3,4,5]
# ----> 2 b = dict(a)
#       3 b
#
# TypeError: 'dict' object is not callable
