# %%
inventors="Edison,tesla,marconi,newton"
inventors.split(",")
watches="rolex hublot cartier"
watches.split()
# Out:
# ['rolex', 'hublot', 'cartier']

# %%
string="dollar"
print(string[0])
string[0]="c"

print(string)
string2="c"+string[1:]
print(string2)
# Out:
# d
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-8fd54b86823d> in <cell line: 0>()
#       1 string="dollar"
#       2 print(string[0])
# ----> 3 string[0]="c"
#       4
#       5 print(string)
#
# TypeError: 'str' object does not support item assignment

# %%
print(r"\nWelcome")
# Out:
# \nWelcome

# %%
print("aplle is a fruit".split("is"))
# Out:
# ['aplle ', ' a fruit']

# %%
print("\tapple".lstrip())
# Out:
# apple

# %%
print("\tapple".lstrip())
# Out:
# apple

# %%
print("\tapple".lstrip())
# Out:
# apple

# %%
print("hello""newline")
# Out:
# hellonewline

# %%
n=input("Enter")
c=len(n)
sum=0
for i in n:
  c=c-1
  sum=sum+(int(i)*(2**(c)))
print(sum)
# Out:
# Enter11001
# 25

# %%
vow=["a","e","i","o","u"]
list1=[]
n=input("Str")
list1.extend(n)
for i in list1:
  if i in vow:
    list1.remove(i)
print(list1)
# Out:
# Stralen
# ['l', 'n']

# %%
#program to extract the first n characters of a string
n=int(input("Enter"))
string=input("Enter")
print(string[:n])
# Out:
# Enter4
# Enteralenmon
# alen
